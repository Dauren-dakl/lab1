# %% [markdown]
# **1 Установка имени и электронной почты**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Имя ветки по умолчанию**
#
# ![Снимок экрана 2025-01-18 031402.png](<attachment:Снимок экрана 2025-01-18 031402.png>)

# %% [markdown]
# **2. Создание проекта**
#
# ![Снимок экрана 2025-01-18 033159.png](<attachment:Снимок экрана 2025-01-18 033159.png>)
#
# **Создайте репозиторий**
#
# ![Снимок экрана 2025-01-18 033404.png](<attachment:Снимок экрана 2025-01-18 033404.png>)
#
# **Добавьте страницу в репозиторий**
#
# ![Снимок экрана 2025-01-18 033548.png](<attachment:Снимок экрана 2025-01-18 033548.png>)

# %% [markdown]
# **3. Проверка состояния**
#
# ![Снимок экрана 2025-01-18 033637.png](<attachment:Снимок экрана 2025-01-18 033637.png>)
#
# ****

# %% [markdown]
# **4 Проверьте состояние**
#
# ![Снимок экрана 2025-01-18 153843.png](<attachment:Снимок экрана 2025-01-18 153843.png>)

# %% [markdown]
# **5 Добавьте изменения**
# **Теперь дайте команду Git проиндексировать изменения. Проверьте состояние:**
#
# ![Снимок экрана 2025-01-18 154653.png](<attachment:Снимок экрана 2025-01-18 154653.png>)

# %% [markdown]
# **6. Индексация и коммит**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **7 Коммит изменений**
#
# ![Снимок экрана 2025-01-18 163836.png](<attachment:Снимок экрана 2025-01-18 163836.png>)
#
# ![Снимок экрана 2025-01-18 163953.png](<attachment:Снимок экрана 2025-01-18 163953.png>)
#
# **проверить состояние**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **8 Изменения, а не файлы**
#
# **01,02,03,04 шаги проверить текущий статус**
#
# ![image.png](attachment:image.png)
#
# **05Commit**
#
# ![image-2.png](attachment:image-2.png)
#
# **06добавить второе изменение**
#
# ![image-3.png](attachment:image-3.png)
#
# **07Сделать коммит второго изменения**
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# **9. История**
#
# ![image.png](attachment:image.png)
#
# **01 Однострочная история**
#
# ![image-2.png](attachment:image-2.png)
#
#
# **03 и 04 швги Конечный формат лога**
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# **10. Получение устаревшей версии**
#
# **01Получить хеши предыдущих коммитов**
#
# ![Снимок экрана 2025-01-18 171246.png](<attachment:Снимок экрана 2025-01-18 171246.png>)
#
#
# ![image.png](attachment:image.png)
#
# **02 Вернитесь к последней версии в веткеmain**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **11. Создание тегов версий**
#
# ![image.png](attachment:image.png)
#
#
# **02Теги для предыдущих версий**
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
#
# **03Переключение по имени тега**
#
# ![image-4.png](attachment:image-4.png)
#
# **04Просмотр тегов с помощью команды tag**
#
# ![image-5.png](attachment:image-5.png)
#
# **05Просмотр Тегов в логах**
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# **12. Отмена локальных изменений (до индексации)**
#
# **01, 02, 03 steps**
#
# ![image.png](attachment:image.png)
#
#
# **04Отмена изменений в рабочем каталоге**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **13. Отмена проиндексированных изменений (перед коммитом)**
#
# **01, 02 steps**
#
# ![image.png](attachment:image.png)
#
# **03Восстановление индекса**
#
# ![image-2.png](attachment:image-2.png)
#
# **04Восстановление рабочего каталога**
#
# ![image-3.png](attachment:image-3.png)
